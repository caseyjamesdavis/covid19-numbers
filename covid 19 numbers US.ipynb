# %%
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', 14)

import numpy as np
from numpy import log as ln

import matplotlib.pyplot as plt
from matplotlib import cm

import squarify

# from IPython.core.display import display, HTML
# display(HTML("<style>.container { width:100% !important; }</style>"))

# %%
input_dir = '/home/cjd/COVID19/'
output_dir = '/home/cjd/COVID19/Output/'

# %%
# !rm $input_dir/*.csv

# !wget https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv
# !wget https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv
# Out:
# --2020-04-13 07:50:06--  https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.248.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.248.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 876432 (856K) [text/plain]
# Saving to: ‘time_series_covid19_confirmed_US.csv’
#
# time_series_covid19 100%[===================>] 855.89K  4.61MB/s    in 0.2s
#
# 2020-04-13 07:50:07 (4.61 MB/s) - ‘time_series_covid19_confirmed_US.csv’ saved [876432/876432]
#
# --2020-04-13 07:50:07--  https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.248.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.248.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 872607 (852K) [text/plain]
# Saving to: ‘time_series_covid19_deaths_US.csv’
#
# time_series_covid19 100%[===================>] 852.16K  4.26MB/s    in 0.2s
#
# 2020-04-13 07:50:07 (4.26 MB/s) - ‘time_series_covid19_deaths_US.csv’ saved [872607/872607]

# %%
cases = pd.read_csv(input_dir + 'time_series_covid19_confirmed_US.csv')
cases = cases.drop(columns=['Lat', 'Long_', 'UID', 'code3', 'FIPS'])

cases = pd.concat([cases.groupby('Province_State').sum()])
cases = cases.sort_values(by=[cases.columns[-1]], ascending=False)

cases = cases.drop(index=['Guam', 'Diamond Princess', 'Virgin Islands', 'Northern Mariana Islands', 'American Samoa', 'Grand Princess', 'Puerto Rico'])

cases
# Out:
#                       1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Province_State
# New York                    0        0        0        0        0        0
# New Jersey                  0        0        0        0        0        0
# Massachusetts               0        0        0        0        0        0
# Michigan                    0        0        0        0        0        0
# Pennsylvania                0        0        0        0        0        0
# California                  0        0        0        0        2        2
# Illinois                    0        0        1        1        1        1
# Louisiana                   0        0        0        0        0        0
# Florida                     0        0        0        0        0        0
# Texas                       0        0        0        0        0        0
# Georgia                     0        0        0        0        0        0
# Connecticut                 0        0        0        0        0        0
# Washington                  1        1        1        1        1        1
# Maryland                    0        0        0        0        0        0
# Indiana                     0        0        0        0        0        0
# Colorado                    0        0        0        0        0        0
# Ohio                        0        0        0        0        0        0
# Tennessee                   0        0        0        0        0        0
# Virginia                    0        0        0        0        0        0
# North Carolina              0        0        0        0        0        0
# Missouri                    0        0        0        0        0        0
# Alabama                     0        0        0        0        0        0
# Arizona                     0        0        0        0        1        1
# Wisconsin                   0        0        0        0        0        0
# South Carolina              0        0        0        0        0        0
# Nevada                      0        0        0        0        0        0
# Mississippi                 0        0        0        0        0        0
# Rhode Island                0        0        0        0        0        0
# Utah                        0        0        0        0        0        0
# Oklahoma                    0        0        0        0        0        0
# Kentucky                    0        0        0        0        0        0
# District of Columbia        0        0        0        0        0        0
# Delaware                    0        0        0        0        0        0
# Minnesota                   0        0        0        0        0        0
# Iowa                        0        0        0        0        0        0
# Oregon                      0        0        0        0        0        0
# Idaho                       0        0        0        0        0        0
# Kansas                      0        0        0        0        0        0
# Arkansas                    0        0        0        0        0        0
# New Mexico                  0        0        0        0        0        0
# New Hampshire               0        0        0        0        0        0
# Nebraska                    0        0        0        0        0        0
# South Dakota                0        0        0        0        0        0
# Vermont                     0        0        0        0        0        0
# Maine                       0        0        0        0        0        0
# West Virginia               0        0        0        0        0        0
# Hawaii                      0        0        0        0        0        0
# Montana                     0        0        0        0        0        0
# North Dakota                0        0        0        0        0        0
# Alaska                      0        0        0        0        0        0
# Wyoming                     0        0        0        0        0        0
#
#                       1/28/20  ...  4/6/20  4/7/20  4/8/20  4/9/20  4/10/20  \
# Province_State                 ...
# New York                    0  ...  131815  139875  151061  161779   172348
# New Jersey                  0  ...   41090   44416   47437   51027    54588
# Massachusetts               0  ...   13837   15202   16790   18941    20974
# Michigan                    0  ...   17221   18970   20346   21504    22434
# Pennsylvania                0  ...   13127   14853   16631   18300    20051
# California                  2  ...   16019   17351   18897   19710    21081
# Illinois                    1  ...   12262   12271   15078   15079    17887
# Louisiana                   0  ...   14867   16284   17030   18283    19253
# Florida                     0  ...   13324   14545   15456   16364    17531
# Texas                       0  ...    8043    8925    9777   11208    12105
# Georgia                     0  ...    7314    8822    9901   10566    11485
# Connecticut                 0  ...    6906    7781    7781    9784    10538
# Washington                  1  ...    8311    8692    9276    9639    10119
# Maryland                    0  ...    4045    4371    5529    6185     6968
# Indiana                     0  ...    4956    5510    5943    6351     6907
# Colorado                    0  ...    5183    5429    5655    5655     6202
# Ohio                        0  ...    4453    4782    5148    5512     5878
# Tennessee                   0  ...    3802    4139    4363    4634     4891
# Virginia                    0  ...    2878    3335    3645    4042     4509
# North Carolina              0  ...    2962    3299    3499    3736     3965
# Missouri                    0  ...    2736    3130    3209    3432     3897
# Alabama                     0  ...    1952    2169    2328    2703     2947
# Arizona                     1  ...    2732    2870    3036    3018     3112
# Wisconsin                   0  ...    2449    2578    2710    2886     3068
# South Carolina              0  ...    2232    2417    2417    2793     3067
# Nevada                      0  ...    1953    2124    2259    2456     2722
# Mississippi                 0  ...    1738    1915    2003    2260     2469
# Rhode Island                0  ...    1082    1229    1450    1727     1727
# Utah                        0  ...    1680    1746    1855    1856     2103
# Oklahoma                    0  ...    1329    1474    1526    1686     1794
# Kentucky                    0  ...     955    1149    1149    1341     1693
# District of Columbia        0  ...    1097    1211    1440    1523     1660
# Delaware                    0  ...     783     928    1116    1209     1326
# Minnesota                   0  ...     986    1069    1154    1240     1336
# Iowa                        0  ...     946    1046    1145    1270     1388
# Oregon                      0  ...    1068    1132    1181    1321     1322
# Idaho                       0  ...    1101    1170    1210    1232     1354
# Kansas                      0  ...     849     912    1046    1116     1117
# Arkansas                    0  ...     875     946    1000    1119     1171
# New Mexico                  0  ...     757     876     902     865     1081
# New Hampshire               0  ...     715     715     747     819      819
# Nebraska                    0  ...     417     447     519     568      635
# South Dakota                0  ...     288     320     393     447      536
# Vermont                     0  ...     543     575     605     628      679
# Maine                       0  ...     499     519     537     560      586
# West Virginia               0  ...     345     412     483     514      574
# Hawaii                      0  ...     387     410     410     442      442
# Montana                     0  ...     299     319     332     354      365
# North Dakota                0  ...     225     237     251     269      278
# Alaska                      0  ...     190     213     226     235      246
# Wyoming                     0  ...     210     216     221     230      239
#
#                       4/11/20  4/12/20
# Province_State
# New York               181026   189033
# New Jersey              58151    61850
# Massachusetts           22860    25475
# Michigan                23605    24244
# Pennsylvania            21719    22938
# California              21706    22795
# Illinois                19180    20852
# Louisiana               20014    20595
# Florida                 18494    19895
# Texas                   13023    13677
# Georgia                 12159    12452
# Connecticut             11510    12035
# Washington              10434    10609
# Maryland                 7694     8225
# Indiana                  7435     7928
# Colorado                 6513     7307
# Ohio                     6250     6604
# Tennessee                5132     5508
# Virginia                 5077     5274
# North Carolina           4354     4570
# Missouri                 4108     4269
# Alabama                  3217     3563
# Arizona                  3393     3542
# Wisconsin                3213     3341
# South Carolina           3211     3320
# Nevada                   2702     2836
# Mississippi              2642     2781
# Rhode Island             2349     2665
# Utah                     2207     2299
# Oklahoma                 1868     1970
# Kentucky                 1693     1963
# District of Columbia     1778     1875
# Delaware                 1479     1625
# Minnesota                1427     1621
# Iowa                     1510     1587
# Oregon                   1371     1527
# Idaho                    1396     1407
# Kansas                   1275     1344
# Arkansas                 1228     1280
# New Mexico               1091     1245
# New Hampshire             885      929
# Nebraska                  699      791
# South Dakota              626      730
# Vermont                   711      727
# Maine                     616      633
# West Virginia             577      593
# Hawaii                    465      499
# Montana                   377      387
# North Dakota              293      308
# Alaska                    257      272
# Wyoming                   261      270
#
# [51 rows x 82 columns]

# %%
deaths = pd.read_csv(input_dir + 'time_series_covid19_deaths_US.csv')
deaths = deaths.drop(columns=['Lat', 'Long_', 'UID', 'code3', 'FIPS'])

deaths = pd.concat([deaths.groupby('Province_State').sum()])
deaths = deaths.sort_values(by=[deaths.columns[-1]], ascending=False)

deaths = deaths.drop(index=['Guam', 'Diamond Princess', 'Virgin Islands', 'Northern Mariana Islands', 'American Samoa', 'Grand Princess', 'Puerto Rico'])

pop = deaths[['Population',]].copy()

deaths = deaths.drop(columns=['Population'])


deaths
# pop
# Out:
#                       1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Province_State
# New York                    0        0        0        0        0        0
# New Jersey                  0        0        0        0        0        0
# Michigan                    0        0        0        0        0        0
# Louisiana                   0        0        0        0        0        0
# Massachusetts               0        0        0        0        0        0
# Illinois                    0        0        0        0        0        0
# California                  0        0        0        0        0        0
# Pennsylvania                0        0        0        0        0        0
# Connecticut                 0        0        0        0        0        0
# Washington                  0        0        0        0        0        0
# Florida                     0        0        0        0        0        0
# Georgia                     0        0        0        0        0        0
# Indiana                     0        0        0        0        0        0
# Colorado                    0        0        0        0        0        0
# Texas                       0        0        0        0        0        0
# Ohio                        0        0        0        0        0        0
# Maryland                    0        0        0        0        0        0
# Wisconsin                   0        0        0        0        0        0
# Virginia                    0        0        0        0        0        0
# Missouri                    0        0        0        0        0        0
# Arizona                     0        0        0        0        0        0
# Nevada                      0        0        0        0        0        0
# Tennessee                   0        0        0        0        0        0
# Kentucky                    0        0        0        0        0        0
# Oklahoma                    0        0        0        0        0        0
# Mississippi                 0        0        0        0        0        0
# Alabama                     0        0        0        0        0        0
# North Carolina              0        0        0        0        0        0
# South Carolina              0        0        0        0        0        0
# Minnesota                   0        0        0        0        0        0
# Rhode Island                0        0        0        0        0        0
# Kansas                      0        0        0        0        0        0
# Oregon                      0        0        0        0        0        0
# District of Columbia        0        0        0        0        0        0
# Iowa                        0        0        0        0        0        0
# Delaware                    0        0        0        0        0        0
# Idaho                       0        0        0        0        0        0
# Arkansas                    0        0        0        0        0        0
# Vermont                     0        0        0        0        0        0
# New Mexico                  0        0        0        0        0        0
# New Hampshire               0        0        0        0        0        0
# Maine                       0        0        0        0        0        0
# Nebraska                    0        0        0        0        0        0
# Utah                        0        0        0        0        0        0
# Hawaii                      0        0        0        0        0        0
# Alaska                      0        0        0        0        0        0
# North Dakota                0        0        0        0        0        0
# West Virginia               0        0        0        0        0        0
# Montana                     0        0        0        0        0        0
# South Dakota                0        0        0        0        0        0
# Wyoming                     0        0        0        0        0        0
#
#                       1/28/20  ...  4/6/20  4/7/20  4/8/20  4/9/20  4/10/20  \
# Province_State                 ...
# New York                    0  ...    4698    5489    6268    7067     7867
# New Jersey                  0  ...    1003    1232    1504    1709     1932
# Michigan                    0  ...     727     845     959    1076     1276
# Louisiana                   0  ...     512     582     652     702      755
# Massachusetts               0  ...     260     356     433     503      599
# Illinois                    0  ...     307     308     462     462      597
# California                  0  ...     380     432     495     544      583
# Pennsylvania                0  ...     179     247     318     345      418
# Connecticut                 0  ...     206     277     326     380      448
# Washington                  0  ...     381     400     426     456      483
# Florida                     0  ...     236     283     309     354      390
# Georgia                     0  ...     229     329     362     379      416
# Indiana                     0  ...     143     173     203     245      300
# Colorado                    0  ...     150     179     193     193      226
# Texas                       0  ...     150     160     189     210      238
# Ohio                        0  ...     142     167     193     213      231
# Maryland                    0  ...      91     103     124     138      171
# Wisconsin                   0  ...      78      92     100     111      128
# Virginia                    0  ...      66      66      66     109      121
# Missouri                    0  ...      47      65      86      93       99
# Arizona                     0  ...      65      73      80      89       97
# Nevada                      0  ...      46      72      72      81       90
# Tennessee                   0  ...      65      72      80      94       98
# Kentucky                    0  ...      45      65      65      73       90
# Oklahoma                    0  ...      51      67      79      80       88
# Mississippi                 0  ...      51      60      67      76       82
# Alabama                     0  ...      49      64      66      70       80
# North Carolina              0  ...      45      53      66      76       83
# South Carolina              0  ...      48      51      51      67       72
# Minnesota                   0  ...      30      34      39      50       57
# Rhode Island                0  ...      27      30      35      43       43
# Kansas                      0  ...      25      29      34      42       42
# Oregon                      0  ...      27      29      33      44       44
# District of Columbia        0  ...      24      22      27      32       38
# Iowa                        0  ...      25      25      27      29       31
# Delaware                    0  ...      15      16      19      23       32
# Idaho                       0  ...      10      13      15      18       24
# Arkansas                    0  ...      16      18      18      21       21
# Vermont                     0  ...      23      23      23      23       24
# New Mexico                  0  ...      12      13      13      16       17
# New Hampshire               0  ...       9       9      13      21       21
# Maine                       0  ...      10      12      14      16       17
# Nebraska                    0  ...       9      10      12      14       15
# Utah                        0  ...      13      13      13      13       13
# Hawaii                      0  ...       5       5       5       6        6
# Alaska                      0  ...       6       6       7       7        7
# North Dakota                0  ...       3       4       4       5        6
# West Virginia               0  ...       4       4       4       5        5
# Montana                     0  ...       6       6       6       6        6
# South Dakota                0  ...       4       6       6       6        6
# Wyoming                     0  ...       0       0       0       0        0
#
#                       4/11/20  4/12/20
# Province_State
# New York                 8627     9385
# New Jersey               2183     2350
# Michigan                 1384     1479
# Louisiana                 806      840
# Massachusetts             686      756
# Illinois                  677      720
# California                605      641
# Pennsylvania              503      557
# Connecticut               494      554
# Washington                495      506
# Florida                   438      461
# Georgia                   429      433
# Indiana                   330      343
# Colorado                  250      289
# Texas                     266      283
# Ohio                      247      253
# Maryland                  206      236
# Wisconsin                 137      144
# Virginia                  130      141
# Missouri                  116      118
# Arizona                   108      115
# Nevada                    102      112
# Tennessee                 106      106
# Kentucky                   90       97
# Oklahoma                   94       96
# Mississippi                93       96
# Alabama                    92       93
# North Carolina             89       89
# South Carolina             80       82
# Minnesota                  64       70
# Rhode Island               56       63
# Kansas                     55       56
# Oregon                     48       52
# District of Columbia       47       50
# Iowa                       34       41
# Delaware                   33       35
# Idaho                      25       27
# Arkansas                   25       27
# Vermont                    25       27
# New Mexico                 19       26
# New Hampshire              22       23
# Maine                      19       19
# Nebraska                   17       17
# Utah                       13       13
# Hawaii                      8        9
# Alaska                      8        8
# North Dakota                7        7
# West Virginia               5        6
# Montana                     6        6
# South Dakota                6        6
# Wyoming                     0        0
#
# [51 rows x 82 columns]

# %%
deaths_per_day = deaths.diff(axis='columns')
cases_per_day = cases.diff(axis='columns')

# %%
# top_ten = cases.index[0:10].tolist()
calc = pd.DataFrame()

calc['Cases'] = cases.loc[:,cases.columns[-1]]
calc['Deaths'] = deaths.loc[:,deaths.columns[-1]]

calc['Case Fatality Rate'] =  (calc['Deaths'] / calc['Cases']) * 100.0
calc = calc.sort_values(by=['Case Fatality Rate'], ascending=False)


calc.style.bar(subset=['Cases'], align='left', color=['moccasin']).bar(subset=['Deaths'], align='left', color=['lightcoral']).format({"Case Fatality Rate": "{:5,.1f} %",}).set_caption("All States Sorted by CFR")
# Out:
# <style  type="text/css" >
#     #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 12.7%, transparent 12.7%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 15.8%, transparent 15.8%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 100.0%, transparent 100.0%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 100.0%, transparent 100.0%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 0.9%, transparent 0.9%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 1.0%, transparent 1.0%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 0.9%, transparent 0.9%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 1.0%, transparent 1.0%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 5.5%, transparent 5.5%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 5.4%, transparent 5.4%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 6.2%, transparent 6.2%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 5.9%, transparent 5.9%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 4.1%, transparent 4.1%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 3.7%, transparent 3.7%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 0.7%, transparent 0.7%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 0.7%, transparent 0.7%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 1.6%, transparent 1.6%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 1.5%, transparent 1.5%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 0.6%, transparent 0.6%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 0.6%, transparent 0.6%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 10.8%, transparent 10.8%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 9.0%, transparent 9.0%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 3.7%, transparent 3.7%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 3.1%, transparent 3.1%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 1.4%, transparent 1.4%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 1.2%, transparent 1.2%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 3.4%, transparent 3.4%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 2.7%, transparent 2.7%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 32.6%, transparent 32.6%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 25.0%, transparent 25.0%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 0.2%, transparent 0.2%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 0.3%, transparent 0.3%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 6.5%, transparent 6.5%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 4.6%, transparent 4.6%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow17_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 10.9%, transparent 10.9%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow17_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 7.7%, transparent 7.7%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow18_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 1.3%, transparent 1.3%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow18_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 1.0%, transparent 1.0%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow19_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,moccasin 0.7%, transparent 0.7%);
#         }    #T_ec48df28_7d7c_11ea_ae5f_7c6d62764b2brow19_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightcoral 0.6%, tr

# %%
cases_doubling_time = ln(2)/ln(1 + cases.pct_change(axis='columns'))
cases_doubling_time = cases_doubling_time.loc[ :, cases.columns[-14:] ]

cases_doubling_time = cases_doubling_time.sort_values(by=[cases_doubling_time.columns[-1]])

cases_doubling_time = cases_doubling_time.replace([np.inf, -np.inf, 0.0, -0.0], np.nan)


cases_doubling_time.style.background_gradient(cmap='Greens', vmin=1.0, vmax=14.0).format("{:.1f}").set_caption("Doubling Times for Cases in [days] Sorted by Most Recent")
# Out:
# <style  type="text/css" >
#     #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow0_col0 {
#             background-color:  #9ed798;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow0_col1 {
#             background-color:  #2a924a;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow0_col2 {
#             background-color:  #cdecc7;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow0_col3 {
#             background-color:  #e2f4dd;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow0_col4 {
#             background-color:  #a9dca3;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow0_col5 {
#             background-color:  #a9dca3;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow0_col6 {
#             background-color:  #a8dca2;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow0_col7 {
#             background-color:  #cfecc9;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow0_col8 {
#             background-color:  #8ed08b;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow0_col9 {
#             background-color:  #d8f0d2;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow0_col10 {
#             background-color:  #acdea6;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow0_col11 {
#             background-color:  #cfecc9;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow0_col12 {
#             background-color:  #c2e7bb;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow0_col13 {
#             background-color:  #c1e6ba;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow1_col0 {
#             background-color:  #6dc072;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow1_col1 {
#             background-color:  #e6f5e1;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow1_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow1_col3 {
#             background-color:  #d5efcf;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow1_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow1_col5 {
#             background-color:  #ccebc6;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow1_col6 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow1_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow1_col8 {
#             background-color:  #d0edca;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow1_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow1_col10 {
#             background-color:  #c2e7bb;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow1_col11 {
#             background-color:  #dff3da;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow1_col12 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow1_col13 {
#             background-color:  #bde5b6;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow2_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow2_col1 {
#             background-color:  #e7f6e3;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow2_col2 {
#             background-color:  #42ab5d;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow2_col3 {
#             background-color:  #b0dfaa;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow2_col4 {
#             background-color:  #eaf7e6;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow2_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow2_col6 {
#             background-color:  #ddf2d8;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow2_col7 {
#             background-color:  #a5db9f;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow2_col8 {
#             background-color:  #bce4b5;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow2_col9 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow2_col10 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow2_col11 {
#             background-color:  #dcf2d7;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow2_col12 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow2_col13 {
#             background-color:  #b0dfaa;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow3_col0 {
#             background-color:  #b2e0ac;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow3_col1 {
#             background-color:  #68be70;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow3_col2 {
#             background-color:  #70c274;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow3_col3 {
#             background-color:  #3da65a;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow3_col4 {
#             background-color:  #127c39;
#             color:  #f1f1f1;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow3_col5 {
#             background-color:  #76c578;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow3_col6 {
#             background-color:  #48ae60;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow3_col7 {
#             background-color:  #005b25;
#             color:  #f1f1f1;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow3_col8 {
#             background-color:  #52b365;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow3_col9 {
#             background-color:  #43ac5e;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow3_col10 {
#             background-color:  #37a055;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow3_col11 {
#             background-color:  #3ea75a;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow3_col12 {
#             background-color:  #278f48;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow3_col13 {
#             background-color:  #abdda5;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow4_col0 {
#             background-color:  #ebf7e7;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow4_col1 {
#             background-color:  #ceecc8;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow4_col2 {
#             background-color:  #bde5b6;
#             color:  #000000;
#         }    #T_ec8895fa_7d7c_11ea_ae5f_7c6d62764b2brow4_col3 {
#             background-color:  #afdfa8;
#             colo

# %%
deaths_doubling_time = ln(2)/ln(1 + deaths.pct_change(axis='columns'))
deaths_doubling_time = deaths_doubling_time.loc[ :, deaths.columns[-14:] ]

deaths_doubling_time = deaths_doubling_time.sort_values(by=[deaths_doubling_time.columns[-1]])

deaths_doubling_time = deaths_doubling_time.replace([np.inf, -np.inf, 0.0, -0.0], np.nan)


deaths_doubling_time.style.background_gradient(cmap='Reds_r', vmin=1.0, vmax=7.0).format("{:.1f}").set_caption("Doubling Times for Deaths in [days] Sorted by Most Recent")
# Out:
# <ipython-input-9-bc0c7d741a8c>:1: RuntimeWarning: divide by zero encountered in log
#   deaths_doubling_time = ln(2)/ln(1 + deaths.pct_change(axis='columns'))
# <style  type="text/css" >
#     #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow0_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow0_col2 {
#             background-color:  #e83429;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow0_col3 {
#             background-color:  #f85d42;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow0_col4 {
#             background-color:  #840711;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow0_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow0_col6 {
#             background-color:  #f85d42;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow0_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow0_col8 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow0_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow0_col10 {
#             background-color:  #f0402f;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow0_col11 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow0_col12 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow0_col13 {
#             background-color:  #bc141a;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow1_col0 {
#             background-color:  #a10e15;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow1_col1 {
#             background-color:  #fc8565;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow1_col2 {
#             background-color:  #d82422;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow1_col3 {
#             background-color:  #f24734;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow1_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow1_col5 {
#             background-color:  #dc2924;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow1_col6 {
#             background-color:  #d82422;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow1_col7 {
#             background-color:  #b71319;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow1_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow1_col9 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow1_col10 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow1_col11 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow1_col12 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow1_col13 {
#             background-color:  #f6583e;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow2_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow2_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow2_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow2_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow2_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow2_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow2_col6 {
#             background-color:  #a10e15;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow2_col7 {
#             background-color:  #c7171c;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow2_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow2_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow2_col10 {
#             background-color:  #e83429;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow2_col11 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow2_col12 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow2_col13 {
#             background-color:  #f85d42;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow3_col0 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow3_col1 {
#             background-color:  #a81016;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow3_col2 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow3_col3 {
#             background-color:  #fc8f6f;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow3_col4 {
#             background-color:  #f4503a;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow3_col5 {
#             background-color:  #fca78b;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow3_col6 {
#             background-color:  #e22e27;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow3_col7 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow3_col8 {
#             background-color:  #fa6547;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow3_col9 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow3_col10 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow3_col11 {
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow3_col12 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow3_col13 {
#             background-color:  #fc9474;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow4_col0 {
#             background-color:  #a10e15;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow4_col1 {
#             background-color:  #f85d42;
#             color:  #000000;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow4_col2 {
#             background-color:  #7c0510;
#             color:  #f1f1f1;
#         }    #T_ecc74b1a_7d7c_11ea_ae5f_7c6d62764b2brow4_col3 {
#             background-color:  #fc8d6d;
#             colo

# %%
pop['per_thou'] = pop['Population']/1e3
pop['per_million'] = pop['Population']/1e6



cases_pc = cases.div(pop['per_thou'], axis=0).round(3)

cases_pc = cases_pc.loc[ :, cases_pc.columns[-14:] ]
cases_pc = cases_pc.sort_values(by=[cases_pc.columns[-1]], ascending=False)

cases_pc.style.background_gradient(cmap='Blues', vmin=0.1, vmax=1.0).format("{:.1f}").set_caption("Number of Cases per 1000 Sorted by Most Recent")
# Out:
# <style  type="text/css" >
#     #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow0_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow0_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow0_col7 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow0_col8 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow0_col9 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow0_col10 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow0_col11 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow0_col12 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow0_col13 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow1_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow1_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow1_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow1_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow1_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow1_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow1_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow1_col7 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow1_col8 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow1_col9 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow1_col10 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow1_col11 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow1_col12 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow1_col13 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow2_col0 {
#             background-color:  #0d57a1;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow2_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow2_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow2_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow2_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow2_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow2_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow2_col7 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow2_col8 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow2_col9 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow2_col10 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow2_col11 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow2_col12 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow2_col13 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow3_col0 {
#             background-color:  #135fa7;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow3_col1 {
#             background-color:  #083b7c;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow3_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow3_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow3_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow3_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow3_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow3_col7 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow3_col8 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow3_col9 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow3_col10 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow3_col11 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow3_col12 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow3_col13 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow4_col0 {
#             background-color:  #3181bd;
#             color:  #000000;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow4_col1 {
#             background-color:  #0a539e;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow4_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_ed0a978a_7d7c_11ea_ae5f_7c6d62764b2brow4_col3 {
#             background-color:  #08306b;
#             colo

# %%
recent = deaths.loc[ :, deaths.columns[-1:]]

recent = recent.rename(columns={ recent.columns[0]: "deaths" })

recent = recent[recent['deaths']>100]

recent = recent.reset_index()

recent['label'] = recent['Province_State'] + '\n' + recent[recent.columns[-1]].astype(str)

# recent

# %%
# %matplotlib



png_w=10
png_h=10

plt.figure(1, figsize=(png_w, png_h))


plt.set_cmap('terrain')


values = recent['deaths'].to_list()
names = recent['label'].to_list()


# values = squarify.normalize_sizes(values, width, height)


ax = squarify.plot(label=names,sizes=values, alpha=.6, text_kwargs={'fontsize':10})

ax.axis('off')
ax.set_title('Deaths as of '+ deaths.columns[-1] +' (for states with deaths > 100)',fontsize=23,fontweight="bold")


plt.subplots_adjust(left=0, bottom=0, right=1, top=0.95, wspace=0, hspace=0)


plt.savefig(output_dir + 'us_plot_treemap_deaths.png')
# plt.show()
# Out:
# Using matplotlib backend: GTK3Agg

# %%
# %matplotlib

png_w=10
png_h=10

plt.figure(2, figsize=(png_w, png_h))

state_list = [
    'Vermont',
    'New Hampshire',
    'New York',
    'Maryland',
    'Florida',
    'Massachusetts',
    #     'Connecticut',
]

styles = ['b.-','g-.','k--','r:','m.-','co-','ys-']



for i,name in enumerate(state_list):
    
    state_pop = pop['per_thou'].loc[name]

    temp = pd.DataFrame(cases.loc[name, :])

    temp['per capita'] = temp[name] / state_pop

    temp = temp.loc[temp['per capita']>0.1, : ]

    temp = temp.reset_index()



    ax = temp['per capita'].plot(style=styles[i])
    
ax.set_yscale('log')
    
# ax.set_xticks(np.arange(n_days))
# temp = cases.columns[-n_days:].to_list()
# ax.set_xticklabels(temp, rotation=45)

    
ax.set_title('Cases in Select States', fontsize=26)
ax.set_xlabel('Number of Days Since 0.1 Cases per 1000 Residents', fontsize=20)
ax.set_ylabel('Number of Cases per 1000 Residents', fontsize=20)

ax.legend(state_list, loc='upper left', fontsize=20)

ax.grid(True, alpha=0.25)


plt.savefig(output_dir + 'us_plot_cases_log.png')
# plt.show()

# %%
# %matplotlib

png_w=10
png_h=10

plt.figure(3, figsize=(png_w, png_h))

state_list = [
    'Vermont',
#     'New Hampshire',
#     'New York',
    'Maryland',
    'Florida',
#     'Massachusetts',
#         'Connecticut',
]

styles = ['b.-','g-.','k--','r:','m.-','co-','ys-']

n_days=30

for i,name in enumerate(state_list):

    ax = cases_per_day.loc[ name, cases.columns[-n_days:] ].plot(style=styles[i])
    
ax.set_xticks(np.arange(n_days))
temp = cases.columns[-n_days:].to_list()
ax.set_xticklabels(temp, rotation=45)

    
ax.set_title('Cases per Day in Select States', fontsize=26)
ax.set_xlabel('Date', fontsize=20)
ax.set_ylabel('Number of Cases per Day', fontsize=20)

ax.legend(state_list, loc='upper left', fontsize=20)

ax.grid(True, alpha=0.25)


plt.savefig(output_dir + 'us_plot_cases_per_day.png')
# plt.show()

# %%
# name = 'Maryland'

# state_pop = pop['per_million'].loc[name]

# temp = pd.DataFrame(cases.loc[name, :])

# temp['per capita'] = temp[name] / state_pop

# temp = temp.loc[temp['per capita']>1, : ]

# temp = temp.reset_index()

# temp
